# %%
#### 2nd 
def daysSince(a, b):
    return ((int(a[0:4]) - int(b[0:4])) * 12) + int(a[5:7]) - int(b[5:7])


csv_filepaths = tuple(map(
    "/media/t-rex/LEGO USB/{0}.csv".format,['1']
#     ['1','2','3','4','5']
))


startYear, startMonth = int(startD[0:4]), int(startD[5:7])
endYear, endMonth = int(endD[0:4]), int(endD[5:7])


# get top languages
num_top_langs = 5
langs = dict(
    zip(
        [k for k, v in sorted(
            occurrences.items(),
            key=lambda item: item[1],
            reverse=True
        )][:num_top_langs],
        range(num_top_langs)
    )
)


def timeGraphFiles(
    filepaths: list[str] = csv_filepaths,
    ) -> list[list[int]]:

    graphdata = [
        [0, 0, 0, 0, 0]
        for _ in range(
            ((endYear - startYear) * 12) + 
            (endMonth - startMonth) + 1
        )
    ]
    current_check_id = "1"
    current_project_checked = []
    
    for filepath in filepaths:
        with open(filepath) as file:
            for line in file:
                project_id, language, size_in_bytes, date_created = line.split(',')

                if project_id != current_check_id:
                    # if this is a different project then update current_check_id
                    # and reset current_project_checked
                    current_check_id = project_id
                    current_project_checked.clear()
                
                if language in langs and language not in current_project_checked:
                    # if the language is one of the languages that we're tracking
                    # and this isn't a duplicate datapoint, then add it to the
                    # graphdata
                    #print(((int(date_created[0:4]) - startYear) * 12) + 
                    #    (int(date_created[5:7]) - startMonth))
                    graphdata[
                        ((int(date_created[0:4]) - startYear) * 12) + 
                        (int(date_created[5:7]) - startMonth)
                    ][langs[language]] += 1
                    current_project_checked.append(language)

    return graphdata



# returns a list full of DATA over TIME
# timeGraphFiles()

# %%
print("2019-09">endD)
print(endD)
maxumum
# Out:
# True
# 2019-05
# 36707970

# %%
# {k: v for k, v in sorted(top.items(), key=lambda item: int(item[1]),reverse=True)}
# {k: v for k, v in sorted(occurrences.items(), key=lambda item: int(item[1]),reverse=True)}
import numpy as np
import pandas as pd
# df=pd.read_csv('/media/t-rex/LEGO USB/3k.csv', )

elapsed=daysSince(endD,startD)+1
# print(timeGraphFiles())
timeData=np.array(timeGraphFiles())#timeData

dates=pd.date_range(startD, periods=elapsed,freq="1M")

df = pd.DataFrame(timeData, index=dates, columns=langs,)#pd.date_range("1/1/2000", periods=60)
df.plot(title="language popularity",);#logy=True#loglog=True

# %%
import time
rec=time.time()
cid='1'
checked=[]
# maxumum=1_000_000
maxumum=1_000

langs=list({k: v for k, v in sorted(occurrences.items(), key=lambda item: item[1],reverse=True)}.keys())[0:10]

langs={lang:{} for lang in langs}

thisProj=[]
usedWith=[]
#langs used with:
# acosciated langs 
def  commonUses(path):
    with open(path) as f:
        global cid,checked,maxumum,langs,thisProj,usedWith
        for line in f:
            if maxumum !=0:
                #the fisrst line doest break because "language" is not one of the top 5 langs
    #             print(line)
                id,lang,size,date=line.split(',')


                if f"{id},{lang}" not in checked:
    #                 id=row['project_id']
                    if cid!=id:
                        checked=[]
                        cid=id
                        for lang in usedWith:
                            
                            subDict=langs[lang]
                            ogl=lang
                            for lang in thisProj:
                                if lang !=ogl:
                                    
                                    if lang in subDict:
                                        subDict[lang]+=1
                                    else:
                                        subDict[lang]=1  
                        thisProj=[]
                        usedWith=[]
                        
                        
                        
                    thisProj.append(lang)
        
        
                    if lang in langs:
                        usedWith.append(lang)
                    
                        

                        

                    checked.append(f"{id},{lang}")
                    maxumum-=1
print('defed')
for i in range(5):
    maxumum=1_000
    commonUses(f'/media/t-rex/LEGO USB/{i+1}.csv')
    print(i+1)
print('end',time.time()-rec)
# print(langs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 # maxumum=1_000_000
#       6 maxumum=1_000
# ----> 8 langs=list({k: v for k, v in sorted(occurrences.items(), key=lambda item: item[1],reverse=True)}.keys())[0:10]
#      10 langs={lang:{} for lang in langs}
#      12 thisProj=[]
#
# NameError: name 'occurrences' is not defined

# %%
langs={'javascript': {'ruby': 709915, 'cmake': 9052, 'python': 544588, 'java': 480698, 'lua': 27925, 'perl': 187995, 'visual basic': 16393, 'objective-c': 162818, 'shell': 659752, 'c++': 232854, 'c': 272374, 'batchfile': 23890, 'html': 257824, 'csound document': 8, 'objective-c++': 13175, 'makefile': 100717, 'glsl': 3998, 'css': 1305874, 'assembly': 42304, 'c#': 155333, 'ada': 4193, 'pascal': 10455, 'coffeescript': 273911, 'nginx': 2872, 'r': 54612, 'php': 511299, 'postscript': 1975, 'puppet': 21911, 'haskell': 21696, 'xslt': 52707, 'groovy': 50903, 'llvm': 592, 'smalltalk': 6882, 'm': 6775, 'go': 42850, 'bison': 4781, 'emacs lisp': 29668, 'ocaml': 6634, 'perl6': 6716, 'livescript': 4620, 'matlab': 17572, 'tex': 38653, 'fortran': 7010, 'mathematica': 1774, 'apacheconf': 28783, 'standard ml': 2265, 'dtrace': 932, 'applescript': 7704, 'groff': 11218, 'viml': 51305, 'cuda': 2207, 'mercury': 1758, 'scala': 46651, 'd': 22870, 'awk': 18958, 'powershell': 27948, 'sourcepawn': 2377, 'protocol buffer': 2552, 'digital command language': 1423, 'erlang': 30208, 'smarty': 7665, 'qmake': 2949, 'm4': 1050, 'cobol': 859, 'robotframework': 378, 'rust': 8012, 'antlr': 1372, 'actionscript': 28111, 'clojure': 23959, 'emberscript': 228, 'racket': 13551, 'common lisp': 7596, 'xs': 622, 'prolog': 19637, 'logos': 5677, 'xc': 579, 'systemverilog': 776, 'ragel in ruby host': 2642, 'scilab': 10731, 'scheme': 13848, 'eagle': 975, 'kicad': 401, 'pawn': 124, 'gnuplot': 2567, 'plpgsql': 3150, 'sqlpl': 2164, 'plsql': 3155, 'asp': 70532, 'nsis': 2284, 'typescript': 15422, 'gcc machine description': 142, 'nu': 1610, 'supercollider': 3843, 'dot': 7376, 'handlebars': 3696, 'mako': 1286, 'verilog': 3543, 'freemarker': 1309, 'gap': 4574, 'cucumber': 4374, 'unrealscript': 3772, 'arc': 364, 'tcl': 11148, 'gosu': 4419, 'jupyter notebook': 843, 'liquid': 414, 'thrift': 1450, 'factor': 250, 'game maker language': 528, 'arduino': 16535, 'pure data': 966, 'processing': 9448,
smt': 55, 'x10': 10, "ren'py": 1, 'dcpu-16 asm': 27, 'jflex': 34, 'mupad': 20, 'harbour': 130, 'blitzmax': 37, 'logtalk': 62, 'txl': 12, 'propeller spin': 38, 'csound score': 3, 'bro': 123, 'powerbuilder': 1, 'bluespec': 22, "cap'n proto": 140, 'alloy': 60, 'shellsession': 10, 'nit': 17, 'brightscript': 59, 'runoff': 1, 'stan': 5, 'vim script': 52, 'roff': 19, 'labview': 146, 'inform 7': 54, 'shen': 8, 'sed': 2, 'ats': 49, 'grammatical framework': 40, 'gdscript': 149, 'perl 6': 2, 'chapel': 36, 'eq': 1, 'opal': 8, 'click': 6, 'sqf': 186, 'xpages': 21, 'pogoscript': 19, 'papyrus': 22, 'gams': 26, 'gherkin': 5, 'moocode': 11, 'wisp': 19, 'metal': 8, 'zimpl': 42, 'loomscript': 9, 'glyph': 20, 'netlinx': 9, 'grace': 6, 'realbasic': 8, 'ox': 6, 'yasnippet': 3, 'xojo': 11, 'charity': 2, 'angelscript': 1, 'webassembly': 1, 'rich text format': 1, 'shaderlab': 1}, 'shell': {'ruby': 356037, 'batchfile': 29810, 'makefile': 127126, 'python': 484993, 'm4': 1999, 'c++': 293613, 'c': 351981, 'php': 253865, 'cmake': 15296, 'java': 329985, 'lua': 33109, 'perl': 217713, 'visual basic': 16956, 'objective-c': 179225, 'javascript': 659752, 'html': 116708, 'csound document': 13, 'objective-c++': 20278, 'glsl': 4046, 'css': 468653, 'assembly': 68153, 'c#': 91286, 'ada': 5046, 'pascal': 12180, 'coffeescript': 78451, 'emacs lisp': 38927, 'viml': 80478, 'llvm': 902, 'go': 34806, 'ocaml': 8361, 'standard ml': 3004, 'scala': 43596, 'nginx': 3315, 'r': 41771, 'racket': 14237, 'powershell': 23804, 'cuda': 3756, 'tex': 46730, 'groff': 18734, 'postscript': 2512, 'puppet': 26159, 'haskell': 20817, 'clojure': 18962, 'cucumber': 3298, 'mirah': 133, 'sourcepawn': 3374, 'd': 28337, 'plpgsql': 2943, 'groovy': 49759, 'xslt': 57026, 'smalltalk': 7532, 'm': 9894, 'bison': 7235, 'perl6': 8005, 'livescript': 3035, 'matlab': 20747, 'fortran': 10846, 'mathematica': 2445, 'apacheconf': 16899, 'dtrace': 1328, 'applescript': 9006, 'mercury': 3290, 'awk': 30634, 'protocol buffer': 3784, 'digital command language': 2011, 'erlang': 31630, 'common lisp': 8251, 'qmake': 4103, 'cobol': 932, 'robotframework': 323, 'rust': 8717, 'antlr': 1434, 'actionscript': 19242, 'smarty': 5434, 'nsis': 3753, 'xs': 1043, 'prolog': 23132, 'logos': 7053, 'xc': 927, 'systemverilog': 1239, 'ragel in ruby host': 2948, 'scilab': 16272, 'augeas': 963, 'scheme': 14412, 'eagle': 1044, 'kicad': 518, 'pawn': 149, 'gnuplot': 4209, 'sqlpl': 2145, 'plsql': 2998, 'asp': 33987, 'vala': 2375, 'typescript': 13396, 'idl': 8672, 'gcc machine description': 137, 'nu': 1787, '
 'monkey': 44, 'dm': 147, 'sql': 1005, 'self': 123, 'lilypond': 98, 'rouge': 12, 'maxscript': 40, 'oxygene': 107, 'red': 32, 'srecode template': 12, 'lookml': 38, 'mirah': 118, 'labview': 38, 'vim script': 81, 'crystal': 116, 'hyphy': 15, 'dylan': 144, 'realbasic': 29, 'vcl': 313, 'smt': 24, 'x10': 12, 'myghty': 5, 'jflex': 14, 'raml': 18, 'mupad': 5, 'xc': 356, 'vue': 43, 'chapel': 23, 'filebench wml': 2, 'blitzmax': 19, 'logtalk': 86, 'txl': 21, 'redcode': 18, 'bro': 126, 'powerbuilder': 1, 'bluespec': 15, 'dockerfile': 19, 'ceylon': 94, 'pan': 44, "cap'n proto": 101, 'shellsession': 9, 'alloy': 36, 'gdscript': 23, 'uno': 1, 'nit': 11, 'stan': 7, 'propeller spin': 10, 'brightscript': 33, 'roff': 12, 'glyph': 7, 'ncl': 18, 'dcpu-16 asm': 42, 'mtml': 5, 'harbour': 80, 'shen': 8, 'picolisp': 6, 'grammatical framework': 10, 'pogoscript': 21, 'perl 6': 3, 'gherkin': 6, 'volt': 225, 'ats': 42, 'opal': 10, 'wisp': 11, 'netlogo': 47, 'xpages': 8, 'sqf': 88, 'papyrus': 11, 'gams': 9, 'click': 3, 'moocode': 11, 'max/msp': 1, 'zimpl': 32, 'xojo': 10, 'loomscript': 12, 'charity': 1, 'netlinx': 5, 'befunge': 1, 'ox': 3, 'metal': 3, 'grace': 1, 'shaderlab': 1}, 'java': {'cmake': 6382, 'python': 240649, 'lua': 17536, 'perl': 89812, 'visual basic': 9467, 'objective-c': 98114, 'shell': 329985, 'c++': 151358, 'c': 167614, 'javascript': 480698, 'ruby': 204983, 'batchfile': 15426, 'html': 79846, 'csound document': 9, 'objective-c++': 11014, 'makefile': 54593, 'glsl': 2849, 'css': 356964, 'assembly': 27027, 'c#': 70927, 'ada': 3784, 'pascal': 7396, 'coffeescript': 48489, 'nginx': 898, 'r': 27846, 'powershell': 10818, 'cuda': 1424, 'tex': 21824, 'clojure': 14692, 'php': 153174, 'emacs lisp': 15622, 'viml': 20874, 'mirah': 90, 'sourcepawn': 1060, 'llvm': 308, 'ocaml': 4516, 'groff': 7035, 'go': 19848, 'xslt': 34543, 'groovy': 77564, 'digital command language': 1065, 'erlang': 14469, 'applescript': 5072, 'qmake': 1870, 'prolog': 12602, 'scala': 37334, 'cobol': 760, 'robotframework': 177, 'actionscript': 12737, 'protocol buffer': 2669, 'racket': 6747, 'haskell': 12460, 'common lisp': 5340, 'xs': 511, 'logos': 5257, 'perl6': 4247, 'xc': 334, 'smalltalk': 4977, 'm4': 571, 'postscript': 1116, 'systemverilog': 564, 'ragel in ruby host': 1914, 'd': 16359, 'scilab': 4043, 'awk': 10283, 'plpgsql': 1645, 'sqlpl': 1446, 'plsql': 2460, 'asp': 16044, 'dtrace': 556, 'nsis': 1648, 'matlab': 12651, 'idl': 4267, 'typescript': 5655, 'verilog': 2758, 'freemarker': 1
 'augeas': 208, 'red': 31, 'crystal': 80, 'dm': 147, 'mtml': 10, 'arc': 136, 'xc': 284, 'hyphy': 9, 'myghty': 9, 'genshi': 16, 'realbasic': 27, 'etag': 320, 'dockerfile': 18, 'smt': 22, 'x10': 8, 'isabelle': 30, 'hcl': 32, 'picolisp': 10, 'vcl': 538, 'chapel': 11, 'blitzmax': 30, 'dylan': 108, 'logtalk': 90, 'game maker language': 179, 'fancy': 92, 'ncl': 13, 'csound score': 2, 'vim script': 27, 'gettext catalog': 289, 'bro': 62, 'ceylon': 63, 'api blueprint': 59, 'bluespec': 10, 'cartocss': 45, 'pan': 42, 'mirah': 29, 'uno': 1, 'brightscript': 22, 'mupad': 8, 'propeller spin': 23, 'roff': 9, 'glyph': 11, 'dcpu-16 asm': 25, 'alloy': 32, 'gdscript': 43, 'netlinx': 3, 'inform 7': 26, 'pogoscript': 9, 'sqf': 112, 'perl 6': 1, 'jflex': 10, "cap'n proto": 41, 'monkey': 55, 'cycript': 23, 'csound document': 1, 'netlogo': 39, 'filebench wml': 1, 'wisp': 6, 'zimpl': 17, 'grammatical framework': 14, 'redcode': 25, 'xpages': 7, 'shen': 4, 'papyrus': 12, 'xojo': 6, 'moocode': 13, 'shellsession': 8, 'max/msp': 1, 'urweb': 11, 'gherkin': 1, 'gams': 14, 'labview': 46, 'loomscript': 3, 'txl': 9, 'charity': 1, 'befunge': 1, 'nit': 5, 'grace': 3, 'stan': 1, 'ox': 2, 'lookml': 6, 'opal': 1, 'nim': 1}, 'c': {'ruby': 152210, 'batchfile': 15836, 'makefile': 101313, 'python': 260357, 'm4': 1863, 'c++': 382011, 'shell': 351981, 'php': 101549, 'cmake': 16462, 'java': 167614, 'lua': 27992, 'perl': 135679, 'visual basic': 11777, 'objective-c': 211585, 'javascript': 272374, 'html': 46618, 'csound document': 8, 'objective-c++': 22517, 'glsl': 4152, 'css': 183579, 'assembly': 75826, 'c#': 57919, 'ada': 4981, 'pascal': 9404, 'emacs lisp': 22994, 'viml': 33021, 'llvm': 915, 'go': 16368, 'ocaml': 6598, 'standard ml': 2108, 'racket': 9547, 'r': 27922, 'powershell': 9671, 'cuda': 4196, 'tex': 33604, 'groff': 14555, 'mirah': 82, 'sourcepawn': 2601, 'd': 26334, 'plpgsql': 1296, 'groovy': 14660, 'smalltalk': 5692, 'm': 10537, 'bison': 7247, 'perl6': 5961, 'livescript': 998, 'matlab': 20881, 'fortran': 10787, 'mathematica': 2255, 'apacheconf': 5180, 'dtrace': 1287, 'applescript': 6832, 'mercury': 3615, 'scala': 19823, 'xslt': 32440, 'protocol buffer': 2521, 'common lisp': 6330, 'qmake': 4614, 'prolog': 22278, 'rust': 7913, 'puppet': 5873, 'awk': 27719, 'antlr': 749, 'erlang': 19702, 'haskell': 12955, 'idl': 9581, 'actionscript': 8546, 'smarty': 1960, 'coffeescript': 25054, 'xs': 1206, 'clojure': 7953, 'logos': 6920, 'xc': 1076, 'postscript': 1453, 'systemverilog': 1051, 'ragel in ruby host': 2967, 'scilab': 16464, 'augeas': 299, 'scheme': 9949, 'eagle': 1056, 'kicad': 440, 'pawn': 122, 'gnuplot': 3533, 'sqlpl': 954, 'plsql': 1279, 'asp': 20836, 'nsis': 3036, 'vala': 1887, 'typescript': 9581, 'cucumber': 858, 'nu': 1368, 'supercollider': 5474, 'dot': 7755, 'tcl': 14330, 'mako': 339, 'verilog': 4745, 'yacc': 4618, 'lex': 4011, 'freemarker': 191, 'gap': 3215, 'unrealscript': 7397, 'gdb': 216, 'haxe': 2833, 'nemerle': 1396, 'digital command language': 1712, 'arc': 480, 'thrift': 933, 'factor': 221, 'game maker language': 409, 'saltstack': 217, 'arduino': 16607, 'pure data': 1141, 'processing': 7698, 'frege': 892, 'cartocss': 125, 'qml': 1317, 'lilypond': 129, 'renderscript': 433, 'nesc': 844, 'stata': 876, 'ags script': 1094, 'openscad': 706, 'webidl': 141, 'diff': 533, 'flux': 1572, 'swift': 4271, 'gdscript': 199, 'e': 250, 'brainfuck': 408, 'ampl': 165, 'maxscript': 93, 'kotlin': 352, 'f#': 3581, 'delphi': 1859, 'max': 1815, 'hlsl': 86, 'clarion': 255, 'sas': 1883, 'module management system': 796, 'clips': 2447, 'ec': 1998, 'nix': 1009, 'dm': 279, 'ecl': 101, 'coq': 731, 'vhdl': 3229, 'inno setup': 1054, 'ats': 76, 'io': 949, 'xquery': 1078, 'web ontology language': 79, 'gcc machine description': 65, 'parrot': 517, 'nimrod': 570, 'gosu': 739, 'xml': 3235, 'jasmin': 102, 'objective-j': 1061, 'pov-ray sdl': 98, 'bluespec': 54, 'julia': 1904, 'autohotkey': 1309, 'component pascal': 606, 'elixir': 2465, 'rebol': 2776, 'turing': 336, 'piglatin': 270, 'gettext catalog': 196, 'jupyter notebook': 421, 'aspectj': 439, 'coldfusion': 1491, 'harbour': 103, 'forth': 2189, 'igor pro': 187, 'clean': 498, 'elm': 225, 'filebench wml': 2, 'lasso': 313, 'redcode': 32, 'hack': 591, 'mask': 182, 'dart': 1938, 'bitbake': 254, 'krl': 193, 'emberscript': 306, 'limbo': 268, 'terra': 47, 'openedge abl': 3000, 'chuck': 95, '1c enterprise': 12, 'cobol': 754, 'boo': 518, 'xbase': 352, 'pike': 555, 'eiffel': 1068, 'dcpu-16 asm': 55, 'slash': 652, 'blitzbasic': 624, 'purebasic': 132, 'zephir': 125, 'pan': 91, 'nginx': 839, 'volt': 258, 'netlogo': 41, 'etag': 275, 'newlisp': 557, 'ooc': 208, 'abap': 551, 'hy': 58, 'omgrofl': 22, 'cool': 72, 'squirrel': 239, 'ioke': 165, 'lolcode': 74, 'lsl': 391, 'autoit': 357, 'apl': 74, 'pony': 7, 'golo': 25, 'oz': 135, 'moonscript': 397, 'smali': 24, 'j': 225, 'xproc': 173, 'apex': 255, 'rexx': 11, 'tea': 11, 'idris': 189, 'modula-2': 43, 'dogescript': 33, 'agda': 108, 'purescript': 49, 'csound': 7, 'opa': 169, 'fantom': 98, 'handlebars': 361, 'self': 220, 'xtend': 424, 'rouge': 31, 'sql': 597, 'oxygene': 170, 'hcl': 47, 'red': 50, 'srecode template': 15, 'labview': 70, 'crystal': 127, 'hyphy': 17, 'myghty': 9, 'genshi': 22, 'grace': 5, 'dylan': 175, 'realbasic': 19, 'dockerfile': 11, 'smt': 79, 'x10': 12, "ren'py": 1, 'charity': 5, 'jflex': 24, 'api blueprint': 43, 'modelica': 67, 'metal': 15, 'inform 7': 49, 'picolisp': 34, 'bro': 99, 'mtml': 3, 'click': 9, 'isabelle': 49, 'robotframework': 57, 'mupad': 13, 'vue': 20, 'blitzmax': 47, 'logtalk': 86, 'txl': 24, 'ncl': 22, 'graphviz (dot)': 1, 'csound score': 6, 'ceylon': 71, 'cirru': 332, 'jsoniq': 364, 'liquid': 64, 'alloy': 51, 'tla': 2, 'fancy': 203, "cap'n proto": 127, 'vim script': 31, 'urweb': 15, 'shellsession': 10, 'nit': 16, 'runoff': 1, 'vcl': 206, 'stan': 8, 'propeller spin': 45, 'raml': 7, 'roff': 27, 'shen': 7, 'netlinx': 3, 'sed': 2, 'sqf': 271, 'grammatical framework': 38, 'perl 6': 4, 'monkey': 55, 'cycript': 24, 'chapel': 49, 'eq': 1, 'lean': 12, 'max/msp': 2, 'zimpl': 39, 'darcs patch': 1, 'glyph': 36, 'papyrus': 16, 'rich text format': 1, 'moocode': 14, 'pogoscript': 6, 'gams': 12, 'gherkin': 1, 'brightscript': 12, 'xojo': 3, 'loomscript': 8, 'kit': 5, 'befunge': 1, 'wisp': 3, 'opal': 2, 'rpc': 1, 'ox': 4, 'angelscript': 1, 'webassembly': 1, 'nim': 1, 'lookml': 1}, 'makefile': {'ruby': 43762, 'batchfile': 14535, 'python': 100697, 'm4': 1784, 'c++': 87193, 'c': 101313, 'shell': 127126, 'php': 34409, 'cmake': 10326, 'objective-c': 39114, 'lua': 9839, 'java': 54593, 'html': 43976, 'javascript': 100717, 'csound document': 10, 'objective-c++': 8131, 'glsl': 3062, 'css': 86246, 'assembly': 21326, 'emacs lisp': 10033, 'viml': 12163, 'llvm': 784, 'perl': 39122, 'go': 10746, 'ocaml': 3350, 'standard ml': 1415, 'powershell': 4749, 'cuda': 2333, 'tex': 19408, 'groff': 14299, 'postscript': 1467, 'mirah': 56, 'sourcepawn': 2402, 'groovy': 3645, 'smalltalk': 2056, 'm': 2246, 'bison': 6878, 'perl6': 5469, 'livescript': 685, 'matlab': 6245, 'ada': 1594, 'fortran': 3848, 'mathematica': 1421, 'apacheconf': 5674, 'c#': 15027, 'dtrace': 1190, 'applescript': 1309, 'mercury': 684, 'scala': 6553, 'xslt': 12023, 'protocol buffer': 2375, 'digital command language': 1738, 'erlang': 8187, 'smarty': 2311, 'common lisp': 2503, 'awk': 10124, 'puppet': 2167, 'pascal': 3960, 'nsis': 2758, 'actionscript': 2553, 'clojure': 3711, 'coffeescript': 10294, 'xs': 869, 'prolog': 7635, 'logos': 3404, 'xc
 18, 'pike': 127, 'labview': 33, 'moonscript': 176, 'ooc': 41, 'hyphy': 14, 'mtml': 5, 'myghty': 7, 'grace': 4, 'apl': 48, 'cool': 56, 'xproc': 72, 'dylan': 42, 'grammatical framework': 31, 'coq': 471, 'dockerfile': 9, 'smt': 74, 'x10': 10, 'agda': 115, 'xtend': 68, "ren'py": 1, 'modelica': 57, 'charity': 5, 'modula-2': 31, 'jflex': 21, 'ceylon': 11, 'nimrod': 218, 'sql': 77, 'autoit': 100, 'inform 7': 27, 'crystal': 106, 'click': 7, 'mupad': 15, 'pony': 7, 'jasmin': 77, 'chapel': 48, 'redcode': 25, 'ncl': 22, 'csound score': 6, 'csound': 4, 'vim script': 45, 'bro': 53, 'alloy': 40, 'turing': 33, 'tla': 1, "cap'n proto": 116, 'dcpu-16 asm': 3, 'lolcode': 40, 'shellsession': 8, 'purescript': 46, 'nit': 15, 'brightscript': 25, 'runoff': 1, 'realbasic': 10, 'txl': 6, 'volt': 109, 'dm': 50, 'roff': 29, 'tea': 5, 'shen': 4, 'netlinx': 4, 'fantom': 15, 'ioke': 12, 'pogoscript': 15, 'perl 6': 4, 'blitzmax': 23, 'vcl': 118, 'eq': 1, 'smali': 18, 'logtalk': 8, 'omgrofl': 1, 'wisp': 6, 'zimpl': 29, 'darcs patch': 1, 'bluespec': 35, 'vue': 10, 'papyrus': 12, 'sqf': 35, 'stan': 6, 'propeller spin': 22, 'rich text format': 1, 'golo': 7, 'moocode': 8, 'yasnippet': 2, 'gams': 6, 'loomscript': 8, 'glyph': 4, 'rpc': 1, 'ox': 2, 'dogescript': 9, 'angelscript': 1, 'kit': 1, 'webassembly': 1, 'sed': 1, 'lookml': 3, 'xpages': 2}}

# %%
print('importing stuff for ploting')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from hurry.filesize import size,si
import colors as colors
colors.colorDictionary=  {k.lower(): v for k, v in colors.colorDictionary.items()}

from datetime import datetime

import time
start=time.time()
# Out:
# importing stuff for ploting

# %%
##### try histogram

import pandas as pd
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2,5, sharex=True)
fig.suptitle('languages used with:', fontsize=16)
y=0
x=0
dfs=[[None for i in range(5)]for i in range(2)]
if 1:
    for majorLang,d in langs.items():
#     def subGraph(index)
        
#         majorLang=langs.items()
#         d=langs[lang]
        top={k: v for k, v in sorted(d.items(), key=lambda item: item[1],reverse=True)}       


        values=list([list(top.values())[0:5][::-1]])


    #         print(values,list(top.keys())[0:20])

        df = pd.DataFrame(values,index=[1],columns=list(top.keys())[0:5][::-1])#
        color=[]
        for lang in list(top.keys())[0:5][::-1]:
            lang=lang.lower()
            if lang in colors.colorDictionary:

                color.append(colors.colorDictionary[lang]['color'])
            else:
                color.append('k')
        dfs[y][x]=df.iloc[0].plot.barh(ax=axs[y][x],logx=True,xlabel="Size in Bytes", ylabel="Language",color=color,title=majorLang)
        #.xaxis.tick_top()
#         axs[i];

#         xlabels=[]
#         for byte in ax.get_xticks():
#             xlabels.append(size(byte, system=si)+"B")
#         ax.set_xticklabels(xlabels)
        x+=1
        if x==5:
            x=0
            y+=1
mainPlot=time.time()
fig.set_figwidth(10)
print('end')

# %%
dfs[0][0].plot()

# %%
import pandas as pd
import matplotlib as mplt
from num2words import num2words
# fig, axs = plt.subplots(2,5, sharex=True)
# fig.suptitle('languages used with:', fontsize=16)
# y=0
# x=0
ogFig,ogAx=plt.subplots(figsize=(12, 7))
fig, ax = plt.subplots(figsize=(12, 7))

# for majorLang,d in langs.items():
def subGraph(index):
    global fig,ax
#     fig, ax = plt.subplots(figsize=(12, 7))
    majorLang=list(langs.keys())[index]
#     print(majorLang)
    d=langs[majorLang]
#     print(d)
    top={k: v for k, v in sorted(d.items(), key=lambda item: item[1],reverse=True)}       


    values=list([list(top.values())[0:5][::-1]])


#     print(values,list(top.keys())[0:20])

    df = pd.DataFrame(values,index=[1],columns=list(top.keys())[0:5][::-1])#
    color=[]
    for lang in list(top.keys())[0:5][::-1]:
        lang=lang.lower()
        if lang in colors.colorDictionary:

            color.append(colors.colorDictionary[lang]['color'])
        else:
            color.append('k')
#     fig,ax=plt.plot(1,1,figsize=(10, 5))

    df=df.iloc[0].plot.barh(logx=False,xlabel="Usage", ylabel="Language",color=color,title=f"languages a used with {majorLang}");
    xlabels=[]


    for byte in df.get_xticks():

        power=0
        byte=int(byte)

        while byte>=1000:
            byte=int(byte)/1000
            power+=1

        byte=str(byte).replace(".0","")+" KMBTqQ"[power]
        xlabels.append(byte)

    df.set_xticklabels(xlabels)
    for text in df.get_xticklabels():
#         print(dir(text))
        text.set_size(text.get_size()*1.5)
#         # x=text._x
#         text.set_x(100_000)
#         text.set(rotation=-20)
#     ylabels=[]
#     t = df.get_yticklabels()[0]
#     print(dir(t))
# #     help(type(t).set_text)
#     t.set_text("yrdy")
#     for value in ax.get_yticks():
# #         value=text.get_text()
#         print(value)
#         while len(value)<9:
#             value='b'+value
        
#         ylabels.append(value)
#     print(ylabels)
#     ax.set_yticklabels(ylabels)
    
    ylabels=[]
    for text in df.get_yticklabels():
        value=text.get_text()
        while len(value)<11:
            value=' '+value
        ylabels.append(value)
        
        text.set_font("monospace")
        text.set_size(text.get_size()*1.5)
#         print(text.get_text())
    ax.set_yticklabels(ylabels)
    
    
    print(dir)
mainPlot=time.time()
# subGraph(1)
pythonI=None
for i in range(10):
    subGraph(i)
    print(i)
    print(list(langs.keys())[i])
    fig.savefig(f'/var/www/html/img1/{list(langs.keys())[i]}',bbox_inches='tight')
    fig.clf()
pythonI;
print('end')
# Out:
# /tmp/ipykernel_4690/179669840.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df.set_xticklabels(xlabels)
# <built-in function dir>
# 0
# javascript
# /tmp/ipykernel_4690/179669840.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df.set_xticklabels(xlabels)
# /tmp/ipykernel_4690/179669840.py:86: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ylabels)
# <built-in function dir>
# 1
# css
# /tmp/ipykernel_4690/179669840.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df.set_xticklabels(xlabels)
# /tmp/ipykernel_4690/179669840.py:86: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ylabels)
# <built-in function dir>
# 2
# shell
# /tmp/ipykernel_4690/179669840.py:54: UserWarning: FixedFormatter should only be used together with FixedLocator
#   df.set_xticklabels(xlabels)
# ...
